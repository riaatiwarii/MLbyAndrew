# %% [markdown]
# Goals :
# To implement cost function

# %%
import numpy as np
# %matplotlib widget
import matplotlib.pyplot as plt
from lab_utils_uni import plt_intuition,plt_stationary, plt_update_onclick,soup_bowl
plt.style.use('./deeplearning.mplstyle')

# %% [markdown]
# Problem statement:
# I would like to make a model for predicting housing prices based on one parameter and one feature

# %%
x_train=np.array([1.0,2.0])     #in 1000 sq feet
y_train=np.array([300.0,500.0]) #in 1000$

# %% [markdown]
# Computing cost:
#
# where
#     J(w,b)=1/2m ∑𝑖=0𝑚−1 (f(w,b)(x^(i))-y^(i))**2

# %%
def compute_cost(x,y,w,b):
  m=len(x)
  cost_sum=0
  for i in range(m):
    f_wb=w*x[i]+b
    cost=(f_wb-y[i])**2
    cost_sum+=cost
  total_cost=cost_sum/(2*m)
  return total_cost

# %% [markdown]
# cost function intution :
# Below, use the slider control to select the value of  w
#   that minimizes cost. It can take a few seconds for the plot to update.

# %%
plt_intuition(x_train,y_train)
# Out:
# interactive(children=(IntSlider(value=150, description='w', max=400, step=10), Output()), _dom_classes=('widge…

# %% [markdown]
# COST FUNCTION VISUALIZATION-3D
# We will take a lager data set than before for this one to see recognizable patterns in the cost function

# %%
x_train=np.array([1.0,1.7,2.0,2.5,3.0,3.2])     #in 1000 sq feet
y_train=np.array([300.0,400.0,500.0,600.0,700.0,800.0]) #in 1000$
plt.close('all')
fig,ax,dyn_items=plt_stationary(x_train,y_train)
updater=plt_update_onclick(fig,ax,dyn_items,x_train,y_train)
soup_bowl()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
